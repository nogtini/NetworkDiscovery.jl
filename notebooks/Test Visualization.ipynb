# %%
using NetworkDiscovery
rng = MersenneTwister();

# %%
nw = generate_network(rng, 100, 5, 0.3, 0.01)
# Out:
# CommunityNetwork({100, 354} undirected graph,5,[5,4,3,3,3,2,2,5,2,3  …  4,4,1,5,3,1,3,2,1,3],0)
