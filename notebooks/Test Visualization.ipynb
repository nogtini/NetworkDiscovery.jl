# %%
using NetworkDiscovery
rng = MersenneTwister();

# %%
nw = generate_network(rng, 100, 5, 0.3, 0.01)
# Out:
# CommunityNetwork({100, 347} undirected graph,5,[3,2,4,1,4,3,4,1,5,5  …  4,3,3,1,3,3,4,1,1,3],0)

# %%
open("/tmp/network.svg", "w") do f
    writemime(f, MIME("image/svg+xml"), nw)
end
